# %%
import numpy as np
import pandas as pd
import torch.nn as nn
import matplotlib.pyplot as plt
import torch

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(2, 10),
            nn.ReLU(),
            nn.Linear(10, 2),
            nn.ReLU(),
            nn.Linear(2, 2)
        )

    def forward(self, x):
        logits = self.linear_relu_stack(x)
        return logits

# %%
x = torch.tensor(list(range(100)),dtype=torch.float32)

# %%
x[1:2]
# Out:
# tensor([1.])

# %%
model(x[0:1])
# Out:
# tensor([-0.1168], grad_fn=<AddBackward0>)

# %%
X_train = torch.tensor([[0,0],[0,1],[1,0],[1,1]],dtype=torch.float32)
y_train = torch.tensor([0,1,1,0],dtype=torch.long)

# %%
y_train
# Out:
# tensor([0., 1., 1., 0.])

# %%
ce = nn.CrossEntropyLoss()
model = NeuralNetwork()
pred = model(X_train)

loss = ce(pred,y_train)
loss
# Out:
# tensor(0.6883, grad_fn=<NllLossBackward0>)

# %%
model = NeuralNetwork()
opt = torch.optim.Adam(model.parameters(),lr=.001)
ce = nn.CrossEntropyLoss()
loss=1
while loss>0.01:
        prediction = model(X_train)
        print(prediction)
        loss = ce(prediction,y_train)
        loss.backward()
        opt.step()
        opt.zero_grad()
# Out:
# tensor([[-0.3600,  0.6953],
#         [-0.3901,  0.6622],
#         [-0.3391,  0.6554],
#         [-0.3180,  0.6747]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3573,  0.6936],
#         [-0.3865,  0.6629],
#         [-0.3361,  0.6554],
#         [-0.3142,  0.6754]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3547,  0.6918],
#         [-0.3829,  0.6636],
#         [-0.3331,  0.6555],
#         [-0.3105,  0.6761]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3521,  0.6901],
#         [-0.3792,  0.6644],
#         [-0.3302,  0.6555],
#         [-0.3067,  0.6769]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3494,  0.6884],
#         [-0.3755,  0.6651],
#         [-0.3272,  0.6556],
#         [-0.3029,  0.6776]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3468,  0.6867],
#         [-0.3719,  0.6658],
#         [-0.3242,  0.6557],
#         [-0.2991,  0.6783]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3442,  0.6850],
#         [-0.3682,  0.6664],
#         [-0.3212,  0.6557],
#         [-0.2953,  0.6790]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3416,  0.6833],
#         [-0.3645,  0.6671],
#         [-0.3182,  0.6558],
#         [-0.2915,  0.6798]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3390,  0.6816],
#         [-0.3608,  0.6678],
#         [-0.3151,  0.6559],
#         [-0.2876,  0.6805]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3364,  0.6799],
#         [-0.3571,  0.6685],
#         [-0.3121,  0.6559],
#         [-0.2837,  0.6813]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3338,  0.6782],
#         [-0.3534,  0.6692],
#         [-0.3090,  0.6560],
#         [-0.2798,  0.6820]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3311,  0.6765],
#         [-0.3497,  0.6699],
#         [-0.3060,  0.6561],
#         [-0.2759,  0.6828]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3285,  0.6749],
#         [-0.3459,  0.6706],
#         [-0.3029,  0.6562],
#         [-0.2719,  0.6835]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3259,  0.6732],
#         [-0.3422,  0.6713],
#         [-0.2998,  0.6563],
#         [-0.2680,  0.6843]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3233,  0.6715],
#         [-0.3384,  0.6720],
#         [-0.2966,  0.6564],
#         [-0.2640,  0.6851]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3207,  0.6699],
#         [-0.3347,  0.6727],
#         [-0.2935,  0.6564],
#         [-0.2599,  0.6859]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3181,  0.6683],
#         [-0.3309,  0.6734],
#         [-0.2904,  0.6566],
#         [-0.2559,  0.6867]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3155,  0.6667],
#         [-0.3271,  0.6741],
#         [-0.2872,  0.6567],
#         [-0.2518,  0.6875]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3129,  0.6651],
#         [-0.3233,  0.6748],
#         [-0.2840,  0.6568],
#         [-0.2477,  0.6883]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3102,  0.6635],
#         [-0.3195,  0.6756],
#         [-0.2808,  0.6569],
#         [-0.2436,  0.6891]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3076,  0.6619],
#         [-0.3157,  0.6763],
#         [-0.2776,  0.6570],
#         [-0.2395,  0.6898]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3050,  0.6603],
#         [-0.3118,  0.6771],
#         [-0.2743,  0.6572],
#         [-0.2354,  0.6906]], grad_fn=<AddmmBackward0>)
# tensor([[-0.3023,  0.6588],
#         [-0.3080,  0.6778],
#         [-0.2711,  0.6573],
#         [-0.2313,  0.6914]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2997,  0.6572],
#         [-0.3040,  0.6786],
#         [-0.2678,  0.6575],
#         [-0.2270,  0.6923]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2970,  0.6557],
#         [-0.3001,  0.6794],
#         [-0.2645,  0.6576],
#         [-0.2227,  0.6932]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2944,  0.6542],
#         [-0.2962,  0.6802],
#         [-0.2611,  0.6578],
#         [-0.2184,  0.6941]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2917,  0.6527],
#         [-0.2922,  0.6811],
#         [-0.2578,  0.6580],
#         [-0.2140,  0.6951]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2891,  0.6512],
#         [-0.2882,  0.6819],
#         [-0.2544,  0.6582],
#         [-0.2095,  0.6961]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2864,  0.6498],
#         [-0.2842,  0.6827],
#         [-0.2510,  0.6584],
#         [-0.2050,  0.6971]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2837,  0.6483],
#         [-0.2802,  0.6836],
#         [-0.2476,  0.6586],
#         [-0.2004,  0.6981]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2810,  0.6469],
#         [-0.2761,  0.6845],
#         [-0.2442,  0.6588],
#         [-0.1959,  0.6992]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2783,  0.6455],
#         [-0.2721,  0.6853],
#         [-0.2408,  0.6590],
#         [-0.1913,  0.7002]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2756,  0.6440],
#         [-0.2682,  0.6862],
#         [-0.2373,  0.6592],
#         [-0.1868,  0.7012]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2729,  0.6427],
#         [-0.2643,  0.6870],
#         [-0.2338,  0.6594],
#         [-0.1822,  0.7022]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2701,  0.6413],
#         [-0.2603,  0.6878],
#         [-0.2303,  0.6597],
#         [-0.1775,  0.7032]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2674,  0.6399],
#         [-0.2565,  0.6886],
#         [-0.2267,  0.6599],
#         [-0.1728,  0.7043]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2646,  0.6385],
#         [-0.2526,  0.6894],
#         [-0.2232,  0.6602],
#         [-0.1682,  0.7053]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2619,  0.6372],
#         [-0.2488,  0.6902],
#         [-0.2196,  0.6605],
#         [-0.1635,  0.7063]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2591,  0.6358],
#         [-0.2449,  0.6910],
#         [-0.2160,  0.6607],
#         [-0.1587,  0.7074]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2563,  0.6345],
#         [-0.2410,  0.6918],
#         [-0.2124,  0.6610],
#         [-0.1539,  0.7085]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2535,  0.6332],
#         [-0.2371,  0.6927],
#         [-0.2087,  0.6613],
#         [-0.1490,  0.7097]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2507,  0.6319],
#         [-0.2332,  0.6935],
#         [-0.2050,  0.6616],
#         [-0.1440,  0.7109]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2478,  0.6305],
#         [-0.2293,  0.6944],
#         [-0.2014,  0.6619],
#         [-0.1390,  0.7121]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2450,  0.6292],
#         [-0.2255,  0.6952],
#         [-0.1976,  0.6622],
#         [-0.1340,  0.7133]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2421,  0.6280],
#         [-0.2217,  0.6960],
#         [-0.1939,  0.6626],
#         [-0.1289,  0.7145]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2392,  0.6267],
#         [-0.2179,  0.6968],
#         [-0.1901,  0.6629],
#         [-0.1239,  0.7157]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2363,  0.6254],
#         [-0.2142,  0.6976],
#         [-0.1863,  0.6632],
#         [-0.1188,  0.7169]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2334,  0.6241],
#         [-0.2104,  0.6985],
#         [-0.1825,  0.6636],
#         [-0.1136,  0.7181]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2303,  0.6232],
#         [-0.2067,  0.6993],
#         [-0.1787,  0.6639],
#         [-0.1084,  0.7194]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2266,  0.6236],
#         [-0.2028,  0.7004],
#         [-0.1748,  0.6643],
#         [-0.1031,  0.7207]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2229,  0.6240],
#         [-0.1988,  0.7019],
#         [-0.1709,  0.6647],
#         [-0.0977,  0.7220]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2191,  0.6244],
#         [-0.1946,  0.7036],
#         [-0.1670,  0.6651],
#         [-0.0923,  0.7234]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2152,  0.6249],
#         [-0.1903,  0.7056],
#         [-0.1630,  0.6655],
#         [-0.0867,  0.7249]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2113,  0.6253],
#         [-0.1859,  0.7078],
#         [-0.1590,  0.6659],
#         [-0.0811,  0.7263]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2074,  0.6258],
#         [-0.1815,  0.7102],
#         [-0.1550,  0.6664],
#         [-0.0755,  0.7278]], grad_fn=<AddmmBackward0>)
# tensor([[-0.2034,  0.6264],
#         [-0.1770,  0.7128],
#         [-0.1509,  0.6668],
#         [-0.0698,  0.7293]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1994,  0.6269],
#         [-0.1724,  0.7156],
#         [-0.1468,  0.6672],
#         [-0.0640,  0.7309]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1953,  0.6275],
#         [-0.1677,  0.7186],
#         [-0.1427,  0.6677],
#         [-0.0581,  0.7325]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1912,  0.6280],
#         [-0.1630,  0.7216],
#         [-0.1386,  0.6682],
#         [-0.0521,  0.7341]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1871,  0.6286],
#         [-0.1582,  0.7248],
#         [-0.1345,  0.6686],
#         [-0.0462,  0.7357]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1829,  0.6293],
#         [-0.1534,  0.7282],
#         [-0.1303,  0.6691],
#         [-0.0401,  0.7374]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1787,  0.6299],
#         [-0.1485,  0.7317],
#         [-0.1261,  0.6696],
#         [-0.0340,  0.7391]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1744,  0.6305],
#         [-0.1436,  0.7353],
#         [-0.1219,  0.6700],
#         [-0.0278,  0.7408]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1702,  0.6311],
#         [-0.1386,  0.7390],
#         [-0.1176,  0.6705],
#         [-0.0215,  0.7426]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1657,  0.6322],
#         [-0.1337,  0.7428],
#         [-0.1133,  0.6710],
#         [-0.0152,  0.7443]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1611,  0.6335],
#         [-0.1288,  0.7464],
#         [-0.1091,  0.6715],
#         [-0.0089,  0.7461]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1566,  0.6346],
#         [-0.1240,  0.7498],
#         [-0.1047,  0.6720],
#         [-0.0024,  0.7479]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1522,  0.6355],
#         [-0.1194,  0.7529],
#         [-0.1004,  0.6725],
#         [ 0.0040,  0.7497]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1479,  0.6362],
#         [-0.1148,  0.7560],
#         [-0.0960,  0.6730],
#         [ 0.0105,  0.7515]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1436,  0.6367],
#         [-0.1103,  0.7588],
#         [-0.0916,  0.6735],
#         [ 0.0170,  0.7533]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1393,  0.6370],
#         [-0.1058,  0.7615],
#         [-0.0872,  0.6740],
#         [ 0.0236,  0.7551]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1351,  0.6372],
#         [-0.1015,  0.7641],
#         [-0.0828,  0.6746],
#         [ 0.0302,  0.7569]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1310,  0.6372],
#         [-0.0972,  0.7665],
#         [-0.0783,  0.6751],
#         [ 0.0368,  0.7587]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1268,  0.6372],
#         [-0.0929,  0.7689],
#         [-0.0737,  0.6757],
#         [ 0.0436,  0.7606]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1224,  0.6378],
#         [-0.0885,  0.7716],
#         [-0.0689,  0.6764],
#         [ 0.0504,  0.7625]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1179,  0.6385],
#         [-0.0838,  0.7747],
#         [-0.0642,  0.6771],
#         [ 0.0573,  0.7644]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1133,  0.6391],
#         [-0.0792,  0.7779],
#         [-0.0594,  0.6778],
#         [ 0.0643,  0.7663]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1087,  0.6398],
#         [-0.0745,  0.7814],
#         [-0.0545,  0.6785],
#         [ 0.0713,  0.7683]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1041,  0.6405],
#         [-0.0697,  0.7851],
#         [-0.0496,  0.6792],
#         [ 0.0784,  0.7702]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0993,  0.6416],
#         [-0.0649,  0.7890],
#         [-0.0447,  0.6800],
#         [ 0.0855,  0.7722]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0945,  0.6426],
#         [-0.0601,  0.7927],
#         [-0.0398,  0.6807],
#         [ 0.0927,  0.7742]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0898,  0.6434],
#         [-0.0554,  0.7962],
#         [-0.0349,  0.6814],
#         [ 0.0999,  0.7762]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0851,  0.6439],
#         [-0.0507,  0.7996],
#         [-0.0299,  0.6821],
#         [ 0.1073,  0.7783]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0805,  0.6443],
#         [-0.0460,  0.8028],
#         [-0.0249,  0.6828],
#         [ 0.1147,  0.7803]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0760,  0.6445],
#         [-0.0415,  0.8059],
#         [-0.0199,  0.6835],
#         [ 0.1220,  0.7823]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0712,  0.6452],
#         [-0.0369,  0.8093],
#         [-0.0149,  0.6842],
#         [ 0.1295,  0.7843]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0664,  0.6459],
#         [-0.0323,  0.8129],
#         [-0.0098,  0.6850],
#         [ 0.1369,  0.7863]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0615,  0.6467],
#         [-0.0275,  0.8169],
#         [-0.0047,  0.6857],
#         [ 0.1444,  0.7883]], grad_fn=<AddmmBackward0>)
# tensor([[-5.6613e-02,  6.4742e-01],
#         [-2.2777e-02,  8.2067e-01],
#         [ 4.3035e-04,  6.8646e-01],
#         [ 1.5207e-01,  7.9041e-01]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0518,  0.6480],
#         [-0.0181,  0.8243],
#         [ 0.0056,  0.6872],
#         [ 0.1598,  0.7925]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0468,  0.6488],
#         [-0.0132,  0.8282],
#         [ 0.0108,  0.6879],
#         [ 0.1676,  0.7947]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0419,  0.6495],
#         [-0.0085,  0.8320],
#         [ 0.0160,  0.6887],
#         [ 0.1756,  0.7969]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0369,  0.6502],
#         [-0.0036,  0.8360],
#         [ 0.0212,  0.6894],
#         [ 0.1835,  0.7990]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0320,  0.6508],
#         [ 0.0010,  0.8399],
#         [ 0.0265,  0.6902],
#         [ 0.1913,  0.8011]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0270,  0.6517],
#         [ 0.0058,  0.8440],
#         [ 0.0318,  0.6910],
#         [ 0.1993,  0.8032]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0220,  0.6524],
#         [ 0.0105,  0.8481],
#         [ 0.0372,  0.6917],
#         [ 0.2075,  0.8057]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0172,  0.6528],
#         [ 0.0149,  0.8510],
#         [ 0.0423,  0.6923],
#         [ 0.2155,  0.8082]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0123,  0.6534],
#         [ 0.0191,  0.8533],
#         [ 0.0473,  0.6929],
#         [ 0.2231,  0.8097]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0073,  0.6540],
#         [ 0.0230,  0.8553],
#         [ 0.0523,  0.6933],
#         [ 0.2305,  0.8110]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0023,  0.6546],
#         [ 0.0271,  0.8577],
#         [ 0.0573,  0.6938],
#         [ 0.2382,  0.8128]], grad_fn=<AddmmBackward0>)
# tensor([[0.0027, 0.6552],
#         [0.0313, 0.8607],
#         [0.0624, 0.6943],
#         [0.2460, 0.8146]], grad_fn=<AddmmBackward0>)
# tensor([[0.0079, 0.6559],
#         [0.0357, 0.8640],
#         [0.0676, 0.6949],
#         [0.2538, 0.8164]], grad_fn=<AddmmBackward0>)
# tensor([[0.0130, 0.6566],
#         [0.0402, 0.8678],
#         [0.0728, 0.6954],
#         [0.2619, 0.8190]], grad_fn=<AddmmBackward0>)
# tensor([[0.0182, 0.6573],
#         [0.0447, 0.8711],
#         [0.0779, 0.6959],
#         [0.2700, 0.8209]], grad_fn=<AddmmBackward0>)
# tensor([[0.0235, 0.6580],
#         [0.0492, 0.8739],
#         [0.0830, 0.6964],
#         [0.2778, 0.8221]], grad_fn=<AddmmBackward0>)
# tensor([[0.0287, 0.6587],
#         [0.0538, 0.8771],
#         [0.0881, 0.6969],
#         [0.2857, 0.8239]], grad_fn=<AddmmBackward0>)
# tensor([[0.0341, 0.6595],
#         [0.0584, 0.8808],
#         [0.0933, 0.6974],
#         [0.2938, 0.8259]], grad_fn=<AddmmBackward0>)
# tensor([[0.0394, 0.6602],
#         [0.0628, 0.8839],
#         [0.0984, 0.6978],
#         [0.3017, 0.8275]], grad_fn=<AddmmBackward0>)
# tensor([[0.0449, 0.6610],
#         [0.0673, 0.8875],
#         [0.1036, 0.6983],
#         [0.3098, 0.8293]], grad_fn=<AddmmBackward0>)
# tensor([[0.0504, 0.6622],
#         [0.0718, 0.8915],
#         [0.1088, 0.6988],
#         [0.3181, 0.8317]], grad_fn=<AddmmBackward0>)
# tensor([[0.0558, 0.6630],
#         [0.0761, 0.8944],
#         [0.1139, 0.6992],
#         [0.3260, 0.8329]], grad_fn=<AddmmBackward0>)
# tensor([[0.0612, 0.6635],
#         [0.0805, 0.8973],
#         [0.1191, 0.6996],
#         [0.3342, 0.8346]], grad_fn=<AddmmBackward0>)
# tensor([[0.0666, 0.6639],
#         [0.0848, 0.9002],
#         [0.1243, 0.7000],
#         [0.3424, 0.8364]], grad_fn=<AddmmBackward0>)
# tensor([[0.0721, 0.6647],
#         [0.0893, 0.9036],
#         [0.1295, 0.7005],
#         [0.3507, 0.8382]], grad_fn=<AddmmBackward0>)
# tensor([[0.0777, 0.6655],
#         [0.0938, 0.9075],
#         [0.1349, 0.7009],
#         [0.3590, 0.8402]], grad_fn=<AddmmBackward0>)
# tensor([[0.0831, 0.6661],
#         [0.0981, 0.9103],
#         [0.1401, 0.7013],
#         [0.3673, 0.8418]], grad_fn=<AddmmBackward0>)
# tensor([[0.0887, 0.6669],
#         [0.1026, 0.9137],
#         [0.1453, 0.7017],
#         [0.3758, 0.8436]], grad_fn=<AddmmBackward0>)
# tensor([[0.0943, 0.6676],
#         [0.1071, 0.9175],
#         [0.1507, 0.7022],
#         [0.3843, 0.8457]], grad_fn=<AddmmBackward0>)
# tensor([[0.1000, 0.6684],
#         [0.1114, 0.9208],
#         [0.1559, 0.7026],
#         [0.3926, 0.8472]], grad_fn=<AddmmBackward0>)
# tensor([[0.1056, 0.6691],
#         [0.1157, 0.9237],
#         [0.1611, 0.7029],
#         [0.4009, 0.8488]], grad_fn=<AddmmBackward0>)
# tensor([[0.1113, 0.6699],
#         [0.1202, 0.9272],
#         [0.1664, 0.7033],
#         [0.4094, 0.8506]], grad_fn=<AddmmBackward0>)
# tensor([[0.1171, 0.6710],
#         [0.1248, 0.9311],
#         [0.1717, 0.7037],
#         [0.4180, 0.8523]], grad_fn=<AddmmBackward0>)
# tensor([[0.1230, 0.6720],
#         [0.1292, 0.9350],
#         [0.1771, 0.7041],
#         [0.4259, 0.8537]], grad_fn=<AddmmBackward0>)
# tensor([[0.1287, 0.6727],
#         [0.1339, 0.9389],
#         [0.1825, 0.7045],
#         [0.4339, 0.8550]], grad_fn=<AddmmBackward0>)
# tensor([[0.1345, 0.6732],
#         [0.1389, 0.9430],
#         [0.1879, 0.7049],
#         [0.4424, 0.8570]], grad_fn=<AddmmBackward0>)
# tensor([[0.1401, 0.6737],
#         [0.1440, 0.9461],
#         [0.1934, 0.7053],
#         [0.4511, 0.8584]], grad_fn=<AddmmBackward0>)
# tensor([[0.1459, 0.6744],
#         [0.1493, 0.9500],
#         [0.1990, 0.7058],
#         [0.4601, 0.8603]], grad_fn=<AddmmBackward0>)
# tensor([[0.1518, 0.6752],
#         [0.1549, 0.9545],
#         [0.2047, 0.7064],
#         [0.4694, 0.8624]], grad_fn=<AddmmBackward0>)
# tensor([[0.1576, 0.6759],
#         [0.1606, 0.9595],
#         [0.2105, 0.7069],
#         [0.4790, 0.8654]], grad_fn=<AddmmBackward0>)
# tensor([[0.1634, 0.6766],
#         [0.1665, 0.9642],
#         [0.2161, 0.7074],
#         [0.4878, 0.8672]], grad_fn=<AddmmBackward0>)
# tensor([[0.1693, 0.6773],
#         [0.1722, 0.9682],
#         [0.2216, 0.7078],
#         [0.4964, 0.8681]], grad_fn=<AddmmBackward0>)
# tensor([[0.1750, 0.6780],
#         [0.1774, 0.9718],
#         [0.2270, 0.7081],
#         [0.5048, 0.8693]], grad_fn=<AddmmBackward0>)
# tensor([[0.1809, 0.6787],
#         [0.1827, 0.9759],
#         [0.2325, 0.7085],
#         [0.5134, 0.8708]], grad_fn=<AddmmBackward0>)
# tensor([[0.1868, 0.6794],
#         [0.1878, 0.9805],
#         [0.2381, 0.7089],
#         [0.5222, 0.8724]], grad_fn=<AddmmBackward0>)
# tensor([[0.1927, 0.6803],
#         [0.1929, 0.9855],
#         [0.2438, 0.7094],
#         [0.5308, 0.8739]], grad_fn=<AddmmBackward0>)
# tensor([[0.1988, 0.6814],
#         [0.1979, 0.9903],
#         [0.2495, 0.7098],
#         [0.5395, 0.8754]], grad_fn=<AddmmBackward0>)
# tensor([[0.2047, 0.6823],
#         [0.2027, 0.9950],
#         [0.2552, 0.7103],
#         [0.5483, 0.8770]], grad_fn=<AddmmBackward0>)
# tensor([[0.2106, 0.6824],
#         [0.2074, 0.9985],
#         [0.2606, 0.7106],
#         [0.5570, 0.8784]], grad_fn=<AddmmBackward0>)
# tensor([[0.2164, 0.6828],
#         [0.2120, 1.0020],
#         [0.2662, 0.7109],
#         [0.5658, 0.8799]], grad_fn=<AddmmBackward0>)
# tensor([[0.2224, 0.6835],
#         [0.2167, 1.0061],
#         [0.2718, 0.7113],
#         [0.5746, 0.8814]], grad_fn=<AddmmBackward0>)
# tensor([[0.2284, 0.6842],
#         [0.2217, 1.0109],
#         [0.2775, 0.7117],
#         [0.5833, 0.8828]], grad_fn=<AddmmBackward0>)
# tensor([[0.2345, 0.6849],
#         [0.2271, 1.0163],
#         [0.2832, 0.7121],
#         [0.5925, 0.8853]], grad_fn=<AddmmBackward0>)
# tensor([[0.2405, 0.6856],
#         [0.2324, 1.0212],
#         [0.2889, 0.7125],
#         [0.6016, 0.8872]], grad_fn=<AddmmBackward0>)
# tensor([[0.2466, 0.6863],
#         [0.2377, 1.0258],
#         [0.2944, 0.7127],
#         [0.6108, 0.8884]], grad_fn=<AddmmBackward0>)
# tensor([[0.2527, 0.6870],
#         [0.2432, 1.0299],
#         [0.2998, 0.7129],
#         [0.6194, 0.8889]], grad_fn=<AddmmBackward0>)
# tensor([[0.2588, 0.6879],
#         [0.2485, 1.0346],
#         [0.3052, 0.7132],
#         [0.6282, 0.8903]], grad_fn=<AddmmBackward0>)
# tensor([[0.2649, 0.6886],
#         [0.2536, 1.0392],
#         [0.3108, 0.7135],
#         [0.6368, 0.8916]], grad_fn=<AddmmBackward0>)
# tensor([[0.2709, 0.6891],
#         [0.2584, 1.0437],
#         [0.3163, 0.7137],
#         [0.6456, 0.8928]], grad_fn=<AddmmBackward0>)
# tensor([[0.2769, 0.6896],
#         [0.2632, 1.0481],
#         [0.3218, 0.7140],
#         [0.6544, 0.8942]], grad_fn=<AddmmBackward0>)
# tensor([[0.2830, 0.6903],
#         [0.2679, 1.0531],
#         [0.3275, 0.7143],
#         [0.6634, 0.8956]], grad_fn=<AddmmBackward0>)
# tensor([[0.2891, 0.6911],
#         [0.2726, 1.0586],
#         [0.3332, 0.7146],
#         [0.6726, 0.8978]], grad_fn=<AddmmBackward0>)
# tensor([[0.2951, 0.6915],
#         [0.2771, 1.0629],
#         [0.3387, 0.7148],
#         [0.6814, 0.8988]], grad_fn=<AddmmBackward0>)
# tensor([[0.3012, 0.6921],
#         [0.2819, 1.0668],
#         [0.3440, 0.7150],
#         [0.6899, 0.8994]], grad_fn=<AddmmBackward0>)
# tensor([[0.3073, 0.6927],
#         [0.2869, 1.0715],
#         [0.3495, 0.7152],
#         [0.6988, 0.9007]], grad_fn=<AddmmBackward0>)
# tensor([[0.3134, 0.6934],
#         [0.2920, 1.0769],
#         [0.3550, 0.7154],
#         [0.7079, 0.9021]], grad_fn=<AddmmBackward0>)
# tensor([[0.3197, 0.6946],
#         [0.2972, 1.0829],
#         [0.3607, 0.7156],
#         [0.7173, 0.9044]], grad_fn=<AddmmBackward0>)
# tensor([[0.3258, 0.6951],
#         [0.3019, 1.0876],
#         [0.3661, 0.7158],
#         [0.7261, 0.9052]], grad_fn=<AddmmBackward0>)
# tensor([[0.3318, 0.6952],
#         [0.3061, 1.0911],
#         [0.3712, 0.7158],
#         [0.7343, 0.9056]], grad_fn=<AddmmBackward0>)
# tensor([[0.3379, 0.6958],
#         [0.3103, 1.0953],
#         [0.3765, 0.7158],
#         [0.7426, 0.9065]], grad_fn=<AddmmBackward0>)
# tensor([[0.3441, 0.6964],
#         [0.3145, 1.1002],
#         [0.3818, 0.7159],
#         [0.7509, 0.9073]], grad_fn=<AddmmBackward0>)
# tensor([[0.3503, 0.6970],
#         [0.3190, 1.1057],
#         [0.3873, 0.7161],
#         [0.7594, 0.9083]], grad_fn=<AddmmBackward0>)
# tensor([[0.3566, 0.6984],
#         [0.3237, 1.1119],
#         [0.3928, 0.7163],
#         [0.7684, 0.9103]], grad_fn=<AddmmBackward0>)
# tensor([[0.3628, 0.6990],
#         [0.3285, 1.1169],
#         [0.3981, 0.7163],
#         [0.7775, 0.9114]], grad_fn=<AddmmBackward0>)
# tensor([[0.3688, 0.6989],
#         [0.3335, 1.1209],
#         [0.4031, 0.7163],
#         [0.7863, 0.9118]], grad_fn=<AddmmBackward0>)
# tensor([[0.3747, 0.6992],
#         [0.3382, 1.1248],
#         [0.4082, 0.7162],
#         [0.7951, 0.9129]], grad_fn=<AddmmBackward0>)
# tensor([[0.3808, 0.6997],
#         [0.3428, 1.1294],
#         [0.4134, 0.7162],
#         [0.8040, 0.9140]], grad_fn=<AddmmBackward0>)
# tensor([[0.3869, 0.7002],
#         [0.3474, 1.1347],
#         [0.4187, 0.7162],
#         [0.8130, 0.9152]], grad_fn=<AddmmBackward0>)
# tensor([[0.3932, 0.7008],
#         [0.3517, 1.1406],
#         [0.4240, 0.7163],
#         [0.8219, 0.9162]], grad_fn=<AddmmBackward0>)
# tensor([[0.3993, 0.7018],
#         [0.3559, 1.1469],
#         [0.4294, 0.7164],
#         [0.8309, 0.9176]], grad_fn=<AddmmBackward0>)
# tensor([[0.4054, 0.7024],
#         [0.3595, 1.1520],
#         [0.4346, 0.7164],
#         [0.8390, 0.9185]], grad_fn=<AddmmBackward0>)
# tensor([[0.4113, 0.7023],
#         [0.3631, 1.1561],
#         [0.4395, 0.7162],
#         [0.8470, 0.9186]], grad_fn=<AddmmBackward0>)
# tensor([[0.4173, 0.7027],
#         [0.3668, 1.1602],
#         [0.4444, 0.7161],
#         [0.8551, 0.9193]], grad_fn=<AddmmBackward0>)
# tensor([[0.4233, 0.7032],
#         [0.3708, 1.1651],
#         [0.4494, 0.7160],
#         [0.8636, 0.9201]], grad_fn=<AddmmBackward0>)
# tensor([[0.4294, 0.7036],
#         [0.3750, 1.1708],
#         [0.4545, 0.7159],
#         [0.8724, 0.9210]], grad_fn=<AddmmBackward0>)
# tensor([[0.4356, 0.7042],
#         [0.3794, 1.1771],
#         [0.4596, 0.7159],
#         [0.8815, 0.9228]], grad_fn=<AddmmBackward0>)
# tensor([[0.4418, 0.7047],
#         [0.3841, 1.1830],
#         [0.4646, 0.7158],
#         [0.8902, 0.9240]], grad_fn=<AddmmBackward0>)
# tensor([[0.4479, 0.7054],
#         [0.3885, 1.1883],
#         [0.4695, 0.7156],
#         [0.8988, 0.9243]], grad_fn=<AddmmBackward0>)
# tensor([[0.4540, 0.7056],
#         [0.3927, 1.1924],
#         [0.4740, 0.7153],
#         [0.9072, 0.9246]], grad_fn=<AddmmBackward0>)
# tensor([[0.4601, 0.7061],
#         [0.3967, 1.1972],
#         [0.4787, 0.7151],
#         [0.9154, 0.9252]], grad_fn=<AddmmBackward0>)
# tensor([[0.4663, 0.7068],
#         [0.4004, 1.2027],
#         [0.4836, 0.7149],
#         [0.9237, 0.9259]], grad_fn=<AddmmBackward0>)
# tensor([[0.4724, 0.7073],
#         [0.4037, 1.2081],
#         [0.4883, 0.7147],
#         [0.9321, 0.9266]], grad_fn=<AddmmBackward0>)
# tensor([[0.4786, 0.7076],
#         [0.4068, 1.2134],
#         [0.4930, 0.7144],
#         [0.9400, 0.9271]], grad_fn=<AddmmBackward0>)
# tensor([[0.4847, 0.7080],
#         [0.4099, 1.2186],
#         [0.4978, 0.7142],
#         [0.9476, 0.9274]], grad_fn=<AddmmBackward0>)
# tensor([[0.4908, 0.7084],
#         [0.4132, 1.2246],
#         [0.5026, 0.7140],
#         [0.9555, 0.9284]], grad_fn=<AddmmBackward0>)
# tensor([[0.4968, 0.7089],
#         [0.4167, 1.2303],
#         [0.5072, 0.7138],
#         [0.9637, 0.9293]], grad_fn=<AddmmBackward0>)
# tensor([[0.5029, 0.7093],
#         [0.4205, 1.2355],
#         [0.5117, 0.7134],
#         [0.9722, 0.9294]], grad_fn=<AddmmBackward0>)
# tensor([[0.5088, 0.7097],
#         [0.4244, 1.2404],
#         [0.5160, 0.7130],
#         [0.9809, 0.9300]], grad_fn=<AddmmBackward0>)
# tensor([[0.5148, 0.7103],
#         [0.4282, 1.2461],
#         [0.5204, 0.7126],
#         [0.9892, 0.9306]], grad_fn=<AddmmBackward0>)
# tensor([[0.5208, 0.7109],
#         [0.4317, 1.2516],
#         [0.5248, 0.7123],
#         [0.9972, 0.9311]], grad_fn=<AddmmBackward0>)
# tensor([[0.5268, 0.7111],
#         [0.4349, 1.2570],
#         [0.5292, 0.7119],
#         [1.0052, 0.9316]], grad_fn=<AddmmBackward0>)
# tensor([[0.5328, 0.7112],
#         [0.4377, 1.2623],
#         [0.5335, 0.7115],
#         [1.0131, 0.9320]], grad_fn=<AddmmBackward0>)
# tensor([[0.5389, 0.7116],
#         [0.4406, 1.2685],
#         [0.5379, 0.7112],
#         [1.0207, 0.9323]], grad_fn=<AddmmBackward0>)
# tensor([[0.5450, 0.7125],
#         [0.4436, 1.2753],
#         [0.5424, 0.7109],
#         [1.0286, 0.9339]], grad_fn=<AddmmBackward0>)
# tensor([[0.5510, 0.7126],
#         [0.4469, 1.2809],
#         [0.5466, 0.7104],
#         [1.0366, 0.9344]], grad_fn=<AddmmBackward0>)
# tensor([[0.5569, 0.7127],
#         [0.4503, 1.2852],
#         [0.5505, 0.7099],
#         [1.0444, 0.9335]], grad_fn=<AddmmBackward0>)
# tensor([[0.5628, 0.7131],
#         [0.4535, 1.2904],
#         [0.5545, 0.7093],
#         [1.0522, 0.9339]], grad_fn=<AddmmBackward0>)
# tensor([[0.5687, 0.7134],
#         [0.4565, 1.2963],
#         [0.5586, 0.7089],
#         [1.0601, 0.9343]], grad_fn=<AddmmBackward0>)
# tensor([[0.5748, 0.7138],
#         [0.4593, 1.3030],
#         [0.5628, 0.7084],
#         [1.0679, 0.9355]], grad_fn=<AddmmBackward0>)
# tensor([[0.5807, 0.7141],
#         [0.4616, 1.3091],
#         [0.5667, 0.7079],
#         [1.0753, 0.9360]], grad_fn=<AddmmBackward0>)
# tensor([[0.5865, 0.7147],
#         [0.4639, 1.3148],
#         [0.5704, 0.7073],
#         [1.0823, 0.9357]], grad_fn=<AddmmBackward0>)
# tensor([[0.5923, 0.7147],
#         [0.4664, 1.3193],
#         [0.5739, 0.7065],
#         [1.0895, 0.9348]], grad_fn=<AddmmBackward0>)
# tensor([[0.5981, 0.7150],
#         [0.4691, 1.3247],
#         [0.5774, 0.7059],
#         [1.0969, 0.9350]], grad_fn=<AddmmBackward0>)
# tensor([[0.6040, 0.7158],
#         [0.4716, 1.3308],
#         [0.5811, 0.7052],
#         [1.1041, 0.9351]], grad_fn=<AddmmBackward0>)
# tensor([[0.6099, 0.7163],
#         [0.4739, 1.3368],
#         [0.5847, 0.7046],
#         [1.1113, 0.9351]], grad_fn=<AddmmBackward0>)
# tensor([[0.6158, 0.7165],
#         [0.4762, 1.3427],
#         [0.5883, 0.7039],
#         [1.1184, 0.9352]], grad_fn=<AddmmBackward0>)
# tensor([[0.6217, 0.7164],
#         [0.4786, 1.3486],
#         [0.5919, 0.7033],
#         [1.1258, 0.9353]], grad_fn=<AddmmBackward0>)
# tensor([[0.6275, 0.7165],
#         [0.4811, 1.3544],
#         [0.5954, 0.7026],
#         [1.1332, 0.9355]], grad_fn=<AddmmBackward0>)
# tensor([[0.6333, 0.7168],
#         [0.4833, 1.3610],
#         [0.5989, 0.7020],
#         [1.1402, 0.9370]], grad_fn=<AddmmBackward0>)
# tensor([[0.6391, 0.7171],
#         [0.4861, 1.3670],
#         [0.6023, 0.7012],
#         [1.1477, 0.9373]], grad_fn=<AddmmBackward0>)
# tensor([[0.6449, 0.7173],
#         [0.4889, 1.3724],
#         [0.6055, 0.7004],
#         [1.1547, 0.9368]], grad_fn=<AddmmBackward0>)
# tensor([[0.6506, 0.7176],
#         [0.4911, 1.3775],
#         [0.6085, 0.6996],
#         [1.1611, 0.9356]], grad_fn=<AddmmBackward0>)
# tensor([[0.6564, 0.7178],
#         [0.4931, 1.3824],
#         [0.6113, 0.6987],
#         [1.1676, 0.9352]], grad_fn=<AddmmBackward0>)
# tensor([[0.6623, 0.7182],
#         [0.4950, 1.3882],
#         [0.6143, 0.6978],
#         [1.1743, 0.9350]], grad_fn=<AddmmBackward0>)
# tensor([[0.6683, 0.7186],
#         [0.4967, 1.3949],
#         [0.6173, 0.6970],
#         [1.1807, 0.9348]], grad_fn=<AddmmBackward0>)
# tensor([[0.6740, 0.7192],
#         [0.4980, 1.4015],
#         [0.6202, 0.6961],
#         [1.1866, 0.9343]], grad_fn=<AddmmBackward0>)
# tensor([[0.6794, 0.7197],
#         [0.4990, 1.4079],
#         [0.6231, 0.6952],
#         [1.1923, 0.9337]], grad_fn=<AddmmBackward0>)
# tensor([[0.6849, 0.7198],
#         [0.5002, 1.4142],
#         [0.6260, 0.6943],
#         [1.1983, 0.9340]], grad_fn=<AddmmBackward0>)
# tensor([[0.6904, 0.7191],
#         [0.5020, 1.4190],
#         [0.6285, 0.6933],
#         [1.2051, 0.9332]], grad_fn=<AddmmBackward0>)
# tensor([[0.6961, 0.7193],
#         [0.5040, 1.4248],
#         [0.6311, 0.6924],
#         [1.2119, 0.9331]], grad_fn=<AddmmBackward0>)
# tensor([[0.7018, 0.7195],
#         [0.5057, 1.4313],
#         [0.6338, 0.6914],
#         [1.2183, 0.9329]], grad_fn=<AddmmBackward0>)
# tensor([[0.7076, 0.7198],
#         [0.5072, 1.4386],
#         [0.6366, 0.6906],
#         [1.2245, 0.9341]], grad_fn=<AddmmBackward0>)
# tensor([[0.7130, 0.7199],
#         [0.5088, 1.4445],
#         [0.6390, 0.6895],
#         [1.2309, 0.9337]], grad_fn=<AddmmBackward0>)
# tensor([[0.7185, 0.7200],
#         [0.5107, 1.4500],
#         [0.6412, 0.6884],
#         [1.2374, 0.9324]], grad_fn=<AddmmBackward0>)
# tensor([[0.7239, 0.7201],
#         [0.5124, 1.4551],
#         [0.6432, 0.6873],
#         [1.2438, 0.9318]], grad_fn=<AddmmBackward0>)
# tensor([[0.7295, 0.7203],
#         [0.5139, 1.4611],
#         [0.6454, 0.6862],
#         [1.2502, 0.9316]], grad_fn=<AddmmBackward0>)
# tensor([[0.7351, 0.7211],
#         [0.5155, 1.4679],
#         [0.6476, 0.6851],
#         [1.2561, 0.9311]], grad_fn=<AddmmBackward0>)
# tensor([[0.7407, 0.7217],
#         [0.5169, 1.4746],
#         [0.6499, 0.6841],
#         [1.2620, 0.9307]], grad_fn=<AddmmBackward0>)
# tensor([[0.7463, 0.7218],
#         [0.5183, 1.4811],
#         [0.6519, 0.6829],
#         [1.2683, 0.9304]], grad_fn=<AddmmBackward0>)
# tensor([[0.7519, 0.7215],
#         [0.5195, 1.4875],
#         [0.6539, 0.6818],
#         [1.2743, 0.9300]], grad_fn=<AddmmBackward0>)
# tensor([[0.7572, 0.7211],
#         [0.5204, 1.4937],
#         [0.6558, 0.6806],
#         [1.2799, 0.9298]], grad_fn=<AddmmBackward0>)
# tensor([[0.7625, 0.7211],
#         [0.5212, 1.4994],
#         [0.6576, 0.6794],
#         [1.2853, 0.9291]], grad_fn=<AddmmBackward0>)
# tensor([[0.7677, 0.7211],
#         [0.5222, 1.5048],
#         [0.6591, 0.6781],
#         [1.2910, 0.9282]], grad_fn=<AddmmBackward0>)
# tensor([[0.7731, 0.7212],
#         [0.5232, 1.5112],
#         [0.6608, 0.6769],
#         [1.2968, 0.9277]], grad_fn=<AddmmBackward0>)
# tensor([[0.7787, 0.7214],
#         [0.5243, 1.5184],
#         [0.6625, 0.6757],
#         [1.3024, 0.9273]], grad_fn=<AddmmBackward0>)
# tensor([[0.7842, 0.7215],
#         [0.5251, 1.5250],
#         [0.6642, 0.6745],
#         [1.3079, 0.9266]], grad_fn=<AddmmBackward0>)
# tensor([[0.7897, 0.7220],
#         [0.5261, 1.5310],
#         [0.6659, 0.6733],
#         [1.3130, 0.9259]], grad_fn=<AddmmBackward0>)
# tensor([[0.7952, 0.7222],
#         [0.5267, 1.5372],
#         [0.6675, 0.6721],
#         [1.3182, 0.9251]], grad_fn=<AddmmBackward0>)
# tensor([[0.8007, 0.7221],
#         [0.5272, 1.5434],
#         [0.6691, 0.6709],
#         [1.3236, 0.9245]], grad_fn=<AddmmBackward0>)
# tensor([[0.8061, 0.7219],
#         [0.5276, 1.5497],
#         [0.6706, 0.6696],
#         [1.3291, 0.9239]], grad_fn=<AddmmBackward0>)
# tensor([[0.8114, 0.7223],
#         [0.5282, 1.5570],
#         [0.6722, 0.6684],
#         [1.3350, 0.9239]], grad_fn=<AddmmBackward0>)
# tensor([[0.8166, 0.7220],
#         [0.5291, 1.5628],
#         [0.6738, 0.6672],
#         [1.3411, 0.9231]], grad_fn=<AddmmBackward0>)
# tensor([[0.8219, 0.7220],
#         [0.5298, 1.5694],
#         [0.6753, 0.6660],
#         [1.3467, 0.9229]], grad_fn=<AddmmBackward0>)
# tensor([[0.8273, 0.7221],
#         [0.5306, 1.5752],
#         [0.6766, 0.6647],
#         [1.3523, 0.9220]], grad_fn=<AddmmBackward0>)
# tensor([[0.8328, 0.7222],
#         [0.5312, 1.5821],
#         [0.6780, 0.6635],
#         [1.3576, 0.9216]], grad_fn=<AddmmBackward0>)
# tensor([[0.8382, 0.7225],
#         [0.5318, 1.5885],
#         [0.6792, 0.6622],
#         [1.3629, 0.9207]], grad_fn=<AddmmBackward0>)
# tensor([[0.8436, 0.7225],
#         [0.5318, 1.5949],
#         [0.6802, 0.6608],
#         [1.3677, 0.9198]], grad_fn=<AddmmBackward0>)
# tensor([[0.8489, 0.7224],
#         [0.5316, 1.6011],
#         [0.6811, 0.6594],
#         [1.3720, 0.9190]], grad_fn=<AddmmBackward0>)
# tensor([[0.8543, 0.7224],
#         [0.5318, 1.6068],
#         [0.6818, 0.6579],
#         [1.3767, 0.9179]], grad_fn=<AddmmBackward0>)
# tensor([[0.8596, 0.7225],
#         [0.5321, 1.6136],
#         [0.6826, 0.6565],
#         [1.3816, 0.9171]], grad_fn=<AddmmBackward0>)
# tensor([[0.8651, 0.7226],
#         [0.5324, 1.6211],
#         [0.6834, 0.6551],
#         [1.3862, 0.9170]], grad_fn=<AddmmBackward0>)
# tensor([[0.8706, 0.7230],
#         [0.5329, 1.6279],
#         [0.6840, 0.6536],
#         [1.3912, 0.9160]], grad_fn=<AddmmBackward0>)
# tensor([[0.8758, 0.7227],
#         [0.5339, 1.6331],
#         [0.6845, 0.6521],
#         [1.3962, 0.9147]], grad_fn=<AddmmBackward0>)
# tensor([[0.8812, 0.7228],
#         [0.5344, 1.6393],
#         [0.6852, 0.6506],
#         [1.4011, 0.9139]], grad_fn=<AddmmBackward0>)
# tensor([[0.8864, 0.7227],
#         [0.5343, 1.6457],
#         [0.6856, 0.6491],
#         [1.4055, 0.9129]], grad_fn=<AddmmBackward0>)
# tensor([[0.8917, 0.7231],
#         [0.5339, 1.6531],
#         [0.6862, 0.6477],
#         [1.4102, 0.9120]], grad_fn=<AddmmBackward0>)
# tensor([[0.8969, 0.7233],
#         [0.5335, 1.6604],
#         [0.6867, 0.6462],
#         [1.4149, 0.9111]], grad_fn=<AddmmBackward0>)
# tensor([[0.9021, 0.7230],
#         [0.5333, 1.6675],
#         [0.6873, 0.6448],
#         [1.4194, 0.9114]], grad_fn=<AddmmBackward0>)
# tensor([[0.9071, 0.7225],
#         [0.5337, 1.6728],
#         [0.6875, 0.6432],
#         [1.4246, 0.9097]], grad_fn=<AddmmBackward0>)
# tensor([[0.9120, 0.7224],
#         [0.5343, 1.6777],
#         [0.6879, 0.6417],
#         [1.4294, 0.9086]], grad_fn=<AddmmBackward0>)
# tensor([[0.9170, 0.7223],
#         [0.5344, 1.6839],
#         [0.6885, 0.6403],
#         [1.4339, 0.9077]], grad_fn=<AddmmBackward0>)
# tensor([[0.9223, 0.7223],
#         [0.5341, 1.6911],
#         [0.6892, 0.6389],
#         [1.4387, 0.9069]], grad_fn=<AddmmBackward0>)
# tensor([[0.9277, 0.7223],
#         [0.5336, 1.6993],
#         [0.6903, 0.6377],
#         [1.4434, 0.9070]], grad_fn=<AddmmBackward0>)
# tensor([[0.9331, 0.7223],
#         [0.5332, 1.7065],
#         [0.6906, 0.6362],
#         [1.4481, 0.9068]], grad_fn=<AddmmBackward0>)
# tensor([[0.9385, 0.7223],
#         [0.5333, 1.7132],
#         [0.6907, 0.6346],
#         [1.4528, 0.9059]], grad_fn=<AddmmBackward0>)
# tensor([[0.9438, 0.7227],
#         [0.5334, 1.7195],
#         [0.6910, 0.6332],
#         [1.4575, 0.9043]], grad_fn=<AddmmBackward0>)
# tensor([[0.9492, 0.7223],
#         [0.5337, 1.7244],
#         [0.6914, 0.6317],
#         [1.4624, 0.9025]], grad_fn=<AddmmBackward0>)
# tensor([[0.9547, 0.7223],
#         [0.5336, 1.7305],
#         [0.6917, 0.6303],
#         [1.4669, 0.9016]], grad_fn=<AddmmBackward0>)
# tensor([[0.9603, 0.7230],
#         [0.5333, 1.7377],
#         [0.6919, 0.6288],
#         [1.4716, 0.9007]], grad_fn=<AddmmBackward0>)
# tensor([[0.9658, 0.7235],
#         [0.5326, 1.7449],
#         [0.6922, 0.6273],
#         [1.4762, 0.9000]], grad_fn=<AddmmBackward0>)
# tensor([[0.9711, 0.7231],
#         [0.5322, 1.7507],
#         [0.6927, 0.6259],
#         [1.4811, 0.8990]], grad_fn=<AddmmBackward0>)
# tensor([[0.9762, 0.7222],
#         [0.5318, 1.7564],
#         [0.6929, 0.6245],
#         [1.4856, 0.8980]], grad_fn=<AddmmBackward0>)
# tensor([[0.9814, 0.7222],
#         [0.5315, 1.7630],
#         [0.6932, 0.6230],
#         [1.4903, 0.8972]], grad_fn=<AddmmBackward0>)
# tensor([[0.9868, 0.7222],
#         [0.5314, 1.7703],
#         [0.6933, 0.6216],
#         [1.4951, 0.8970]], grad_fn=<AddmmBackward0>)
# tensor([[0.9919, 0.7220],
#         [0.5314, 1.7759],
#         [0.6930, 0.6200],
#         [1.5001, 0.8955]], grad_fn=<AddmmBackward0>)
# tensor([[0.9970, 0.7219],
#         [0.5311, 1.7824],
#         [0.6927, 0.6184],
#         [1.5042, 0.8944]], grad_fn=<AddmmBackward0>)
# tensor([[1.0023, 0.7218],
#         [0.5306, 1.7899],
#         [0.6924, 0.6167],
#         [1.5083, 0.8942]], grad_fn=<AddmmBackward0>)
# tensor([[1.0075, 0.7217],
#         [0.5306, 1.7967],
#         [0.6917, 0.6150],
#         [1.5130, 0.8930]], grad_fn=<AddmmBackward0>)
# tensor([[1.0127, 0.7216],
#         [0.5308, 1.8030],
#         [0.6915, 0.6135],
#         [1.5170, 0.8914]], grad_fn=<AddmmBackward0>)
# tensor([[1.0177, 0.7222],
#         [0.5305, 1.8102],
#         [0.6910, 0.6118],
#         [1.5208, 0.8905]], grad_fn=<AddmmBackward0>)
# tensor([[1.0227, 0.7216],
#         [0.5298, 1.8157],
#         [0.6905, 0.6102],
#         [1.5251, 0.8891]], grad_fn=<AddmmBackward0>)
# tensor([[1.0276, 0.7210],
#         [0.5289, 1.8214],
#         [0.6900, 0.6086],
#         [1.5291, 0.8880]], grad_fn=<AddmmBackward0>)
# tensor([[1.0328, 0.7209],
#         [0.5279, 1.8283],
#         [0.6895, 0.6070],
#         [1.5334, 0.8870]], grad_fn=<AddmmBackward0>)
# tensor([[1.0381, 0.7214],
#         [0.5268, 1.8362],
#         [0.6893, 0.6055],
#         [1.5378, 0.8870]], grad_fn=<AddmmBackward0>)
# tensor([[1.0432, 0.7210],
#         [0.5260, 1.8426],
#         [0.6890, 0.6039],
#         [1.5422, 0.8862]], grad_fn=<AddmmBackward0>)
# tensor([[1.0481, 0.7204],
#         [0.5255, 1.8475],
#         [0.6882, 0.6023],
#         [1.5468, 0.8841]], grad_fn=<AddmmBackward0>)
# tensor([[1.0529, 0.7201],
#         [0.5251, 1.8534],
#         [0.6875, 0.6006],
#         [1.5507, 0.8829]], grad_fn=<AddmmBackward0>)
# tensor([[1.0579, 0.7199],
#         [0.5245, 1.8601],
#         [0.6866, 0.5989],
#         [1.5545, 0.8817]], grad_fn=<AddmmBackward0>)
# tensor([[1.0630, 0.7197],
#         [0.5237, 1.8677],
#         [0.6858, 0.5972],
#         [1.5585, 0.8810]], grad_fn=<AddmmBackward0>)
# tensor([[1.0682, 0.7195],
#         [0.5232, 1.8743],
#         [0.6846, 0.5955],
#         [1.5630, 0.8796]], grad_fn=<AddmmBackward0>)
# tensor([[1.0735, 0.7195],
#         [0.5226, 1.8818],
#         [0.6836, 0.5937],
#         [1.5668, 0.8787]], grad_fn=<AddmmBackward0>)
# tensor([[1.0787, 0.7193],
#         [0.5220, 1.8877],
#         [0.6826, 0.5920],
#         [1.5701, 0.8771]], grad_fn=<AddmmBackward0>)
# tensor([[1.0840, 0.7191],
#         [0.5213, 1.8948],
#         [0.6819, 0.5904],
#         [1.5739, 0.8759]], grad_fn=<AddmmBackward0>)
# tensor([[1.0891, 0.7189],
#         [0.5209, 1.9005],
#         [0.6808, 0.5887],
#         [1.5780, 0.8748]], grad_fn=<AddmmBackward0>)
# tensor([[1.0941, 0.7186],
#         [0.5202, 1.9071],
#         [0.6795, 0.5870],
#         [1.5822, 0.8737]], grad_fn=<AddmmBackward0>)
# tensor([[1.0993, 0.7187],
#         [0.5191, 1.9149],
#         [0.6787, 0.5853],
#         [1.5864, 0.8730]], grad_fn=<AddmmBackward0>)
# tensor([[1.1043, 0.7182],
#         [0.5182, 1.9209],
#         [0.6776, 0.5837],
#         [1.5906, 0.8716]], grad_fn=<AddmmBackward0>)
# tensor([[1.1095, 0.7181],
#         [0.5171, 1.9279],
#         [0.6767, 0.5820],
#         [1.5943, 0.8711]], grad_fn=<AddmmBackward0>)
# tensor([[1.1146, 0.7178],
#         [0.5170, 1.9330],
#         [0.6754, 0.5803],
#         [1.5983, 0.8692]], grad_fn=<AddmmBackward0>)
# tensor([[1.1194, 0.7174],
#         [0.5163, 1.9390],
#         [0.6740, 0.5785],
#         [1.6020, 0.8679]], grad_fn=<AddmmBackward0>)
# tensor([[1.1244, 0.7172],
#         [0.5154, 1.9461],
#         [0.6726, 0.5768],
#         [1.6060, 0.8668]], grad_fn=<AddmmBackward0>)
# tensor([[1.1295, 0.7169],
#         [0.5143, 1.9540],
#         [0.6711, 0.5750],
#         [1.6098, 0.8665]], grad_fn=<AddmmBackward0>)
# tensor([[1.1347, 0.7168],
#         [0.5135, 1.9613],
#         [0.6696, 0.5732],
#         [1.6130, 0.8657]], grad_fn=<AddmmBackward0>)
# tensor([[1.1395, 0.7163],
#         [0.5124, 1.9670],
#         [0.6679, 0.5714],
#         [1.6162, 0.8633]], grad_fn=<AddmmBackward0>)
# tensor([[1.1444, 0.7160],
#         [0.5114, 1.9724],
#         [0.6664, 0.5697],
#         [1.6196, 0.8614]], grad_fn=<AddmmBackward0>)
# tensor([[1.1495, 0.7157],
#         [0.5103, 1.9789],
#         [0.6650, 0.5679],
#         [1.6233, 0.8602]], grad_fn=<AddmmBackward0>)
# tensor([[1.1546, 0.7157],
#         [0.5090, 1.9861],
#         [0.6635, 0.5662],
#         [1.6271, 0.8589]], grad_fn=<AddmmBackward0>)
# tensor([[1.1597, 0.7156],
#         [0.5080, 1.9930],
#         [0.6621, 0.5645],
#         [1.6309, 0.8577]], grad_fn=<AddmmBackward0>)
# tensor([[1.1649, 0.7149],
#         [0.5072, 1.9997],
#         [0.6605, 0.5628],
#         [1.6350, 0.8567]], grad_fn=<AddmmBackward0>)
# tensor([[1.1696, 0.7144],
#         [0.5070, 2.0046],
#         [0.6586, 0.5610],
#         [1.6385, 0.8553]], grad_fn=<AddmmBackward0>)
# tensor([[1.1744, 0.7140],
#         [0.5065, 2.0107],
#         [0.6569, 0.5592],
#         [1.6425, 0.8541]], grad_fn=<AddmmBackward0>)
# tensor([[1.1795, 0.7137],
#         [0.5057, 2.0179],
#         [0.6552, 0.5574],
#         [1.6467, 0.8530]], grad_fn=<AddmmBackward0>)
# tensor([[1.1847, 0.7134],
#         [0.5048, 2.0261],
#         [0.6537, 0.5558],
#         [1.6507, 0.8533]], grad_fn=<AddmmBackward0>)
# tensor([[1.1899, 0.7131],
#         [0.5032, 2.0336],
#         [0.6520, 0.5540],
#         [1.6535, 0.8529]], grad_fn=<AddmmBackward0>)
# tensor([[1.1948, 0.7127],
#         [0.5018, 2.0402],
#         [0.6500, 0.5522],
#         [1.6566, 0.8511]], grad_fn=<AddmmBackward0>)
# tensor([[1.1997, 0.7123],
#         [0.5007, 2.0459],
#         [0.6479, 0.5504],
#         [1.6600, 0.8484]], grad_fn=<AddmmBackward0>)
# tensor([[1.2046, 0.7119],
#         [0.5000, 2.0511],
#         [0.6458, 0.5485],
#         [1.6635, 0.8461]], grad_fn=<AddmmBackward0>)
# tensor([[1.2095, 0.7115],
#         [0.4993, 2.0573],
#         [0.6438, 0.5467],
#         [1.6670, 0.8448]], grad_fn=<AddmmBackward0>)
# tensor([[1.2145, 0.7118],
#         [0.4984, 2.0646],
#         [0.6418, 0.5450],
#         [1.6710, 0.8436]], grad_fn=<AddmmBackward0>)
# tensor([[1.2195, 0.7121],
#         [0.4972, 2.0720],
#         [0.6399, 0.5432],
#         [1.6751, 0.8424]], grad_fn=<AddmmBackward0>)
# tensor([[1.2247, 0.7118],
#         [0.4958, 2.0791],
#         [0.6383, 0.5416],
#         [1.6788, 0.8413]], grad_fn=<AddmmBackward0>)
# tensor([[1.2299, 0.7103],
#         [0.4945, 2.0846],
#         [0.6361, 0.5398],
#         [1.6820, 0.8396]], grad_fn=<AddmmBackward0>)
# tensor([[1.2345, 0.7095],
#         [0.4931, 2.0901],
#         [0.6339, 0.5380],
#         [1.6850, 0.8381]], grad_fn=<AddmmBackward0>)
# tensor([[1.2394, 0.7090],
#         [0.4920, 2.0965],
#         [0.6317, 0.5362],
#         [1.6881, 0.8367]], grad_fn=<AddmmBackward0>)
# tensor([[1.2444, 0.7086],
#         [0.4907, 2.1039],
#         [0.6295, 0.5344],
#         [1.6913, 0.8361]], grad_fn=<AddmmBackward0>)
# tensor([[1.2494, 0.7082],
#         [0.4898, 2.1103],
#         [0.6271, 0.5325],
#         [1.6949, 0.8345]], grad_fn=<AddmmBackward0>)
# tensor([[1.2544, 0.7077],
#         [0.4894, 2.1159],
#         [0.6247, 0.5307],
#         [1.6983, 0.8325]], grad_fn=<AddmmBackward0>)
# tensor([[1.2597, 0.7074],
#         [0.4887, 2.1227],
#         [0.6229, 0.5291],
#         [1.7021, 0.8312]], grad_fn=<AddmmBackward0>)
# tensor([[1.2648, 0.7069],
#         [0.4878, 2.1303],
#         [0.6208, 0.5274],
#         [1.7064, 0.8300]], grad_fn=<AddmmBackward0>)
# tensor([[1.2698, 0.7065],
#         [0.4869, 2.1384],
#         [0.6182, 0.5255],
#         [1.7104, 0.8304]], grad_fn=<AddmmBackward0>)
# tensor([[1.2749, 0.7064],
#         [0.4865, 2.1455],
#         [0.6161, 0.5238],
#         [1.7143, 0.8298]], grad_fn=<AddmmBackward0>)
# tensor([[1.2798, 0.7055],
#         [0.4862, 2.1509],
#         [0.6135, 0.5220],
#         [1.7177, 0.8274]], grad_fn=<AddmmBackward0>)
# tensor([[1.2846, 0.7050],
#         [0.4851, 2.1560],
#         [0.6107, 0.5201],
#         [1.7207, 0.8246]], grad_fn=<AddmmBackward0>)
# tensor([[1.2896, 0.7045],
#         [0.4836, 2.1623],
#         [0.6083, 0.5183],
#         [1.7238, 0.8231]], grad_fn=<AddmmBackward0>)
# tensor([[1.2948, 0.7045],
#         [0.4821, 2.1698],
#         [0.6061, 0.5166],
#         [1.7274, 0.8217]], grad_fn=<AddmmBackward0>)
# tensor([[1.3000, 0.7042],
#         [0.4806, 2.1770],
#         [0.6036, 0.5149],
#         [1.7309, 0.8205]], grad_fn=<AddmmBackward0>)
# tensor([[1.3052, 0.7031],
#         [0.4800, 2.1825],
#         [0.6009, 0.5131],
#         [1.7343, 0.8189]], grad_fn=<AddmmBackward0>)
# tensor([[1.3102, 0.7026],
#         [0.4789, 2.1889],
#         [0.5983, 0.5113],
#         [1.7373, 0.8174]], grad_fn=<AddmmBackward0>)
# tensor([[1.3155, 0.7022],
#         [0.4777, 2.1961],
#         [0.5962, 0.5097],
#         [1.7405, 0.8160]], grad_fn=<AddmmBackward0>)
# tensor([[1.3204, 0.7016],
#         [0.4767, 2.2023],
#         [0.5933, 0.5078],
#         [1.7441, 0.8145]], grad_fn=<AddmmBackward0>)
# tensor([[1.3252, 0.7010],
#         [0.4756, 2.2091],
#         [0.5906, 0.5061],
#         [1.7479, 0.8132]], grad_fn=<AddmmBackward0>)
# tensor([[1.3299, 0.7004],
#         [0.4746, 2.2157],
#         [0.5880, 0.5043],
#         [1.7516, 0.8122]], grad_fn=<AddmmBackward0>)
# tensor([[1.3347, 0.6998],
#         [0.4737, 2.2219],
#         [0.5853, 0.5026],
#         [1.7554, 0.8105]], grad_fn=<AddmmBackward0>)
# tensor([[1.3396, 0.6993],
#         [0.4727, 2.2291],
#         [0.5827, 0.5009],
#         [1.7592, 0.8096]], grad_fn=<AddmmBackward0>)
# tensor([[1.3444, 0.6986],
#         [0.4721, 2.2341],
#         [0.5797, 0.4991],
#         [1.7623, 0.8076]], grad_fn=<AddmmBackward0>)
# tensor([[1.3493, 0.6980],
#         [0.4710, 2.2403],
#         [0.5769, 0.4973],
#         [1.7655, 0.8061]], grad_fn=<AddmmBackward0>)
# tensor([[1.3544, 0.6974],
#         [0.4694, 2.2476],
#         [0.5739, 0.4955],
#         [1.7685, 0.8046]], grad_fn=<AddmmBackward0>)
# tensor([[1.3595, 0.6969],
#         [0.4680, 2.2558],
#         [0.5711, 0.4938],
#         [1.7714, 0.8046]], grad_fn=<AddmmBackward0>)
# tensor([[1.3647, 0.6963],
#         [0.4675, 2.2620],
#         [0.5684, 0.4921],
#         [1.7754, 0.8029]], grad_fn=<AddmmBackward0>)
# tensor([[1.3698, 0.6957],
#         [0.4677, 2.2674],
#         [0.5655, 0.4903],
#         [1.7794, 0.8003]], grad_fn=<AddmmBackward0>)
# tensor([[1.3752, 0.6952],
#         [0.4674, 2.2740],
#         [0.5627, 0.4887],
#         [1.7829, 0.7989]], grad_fn=<AddmmBackward0>)
# tensor([[1.3806, 0.6947],
#         [0.4666, 2.2813],
#         [0.5603, 0.4871],
#         [1.7864, 0.7982]], grad_fn=<AddmmBackward0>)
# tensor([[1.3853, 0.6940],
#         [0.4654, 2.2866],
#         [0.5571, 0.4853],
#         [1.7897, 0.7960]], grad_fn=<AddmmBackward0>)
# tensor([[1.3898, 0.6933],
#         [0.4636, 2.2928],
#         [0.5537, 0.4835],
#         [1.7926, 0.7944]], grad_fn=<AddmmBackward0>)
# tensor([[1.3947, 0.6926],
#         [0.4615, 2.3000],
#         [0.5507, 0.4817],
#         [1.7950, 0.7936]], grad_fn=<AddmmBackward0>)
# tensor([[1.3995, 0.6919],
#         [0.4602, 2.3063],
#         [0.5474, 0.4800],
#         [1.7981, 0.7919]], grad_fn=<AddmmBackward0>)
# tensor([[1.4045, 0.6913],
#         [0.4597, 2.3119],
#         [0.5443, 0.4783],
#         [1.8020, 0.7897]], grad_fn=<AddmmBackward0>)
# tensor([[1.4097, 0.6907],
#         [0.4593, 2.3186],
#         [0.5415, 0.4766],
#         [1.8061, 0.7884]], grad_fn=<AddmmBackward0>)
# tensor([[1.4150, 0.6908],
#         [0.4589, 2.3261],
#         [0.5387, 0.4750],
#         [1.8095, 0.7871]], grad_fn=<AddmmBackward0>)
# tensor([[1.4202, 0.6900],
#         [0.4582, 2.3318],
#         [0.5355, 0.4733],
#         [1.8130, 0.7854]], grad_fn=<AddmmBackward0>)
# tensor([[1.4253, 0.6888],
#         [0.4572, 2.3377],
#         [0.5321, 0.4716],
#         [1.8164, 0.7839]], grad_fn=<AddmmBackward0>)
# ...
# tensor([[ 6.5545, -0.2953],
#         [-0.1180,  7.7374],
#         [-1.6778,  1.4938],
#         [ 6.8777, -0.3655]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5552, -0.2954],
#         [-0.1184,  7.7384],
#         [-1.6782,  1.4942],
#         [ 6.8780, -0.3656]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5560, -0.2955],
#         [-0.1188,  7.7396],
#         [-1.6785,  1.4945],
#         [ 6.8785, -0.3657]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5568, -0.2957],
#         [-0.1192,  7.7407],
#         [-1.6789,  1.4949],
#         [ 6.8791, -0.3658]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5577, -0.2959],
#         [-0.1194,  7.7418],
#         [-1.6792,  1.4952],
#         [ 6.8798, -0.3659]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5586, -0.2961],
#         [-0.1196,  7.7430],
#         [-1.6796,  1.4955],
#         [ 6.8808, -0.3661]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5596, -0.2963],
#         [-0.1197,  7.7441],
#         [-1.6799,  1.4959],
#         [ 6.8818, -0.3663]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5606, -0.2965],
#         [-0.1198,  7.7453],
#         [-1.6802,  1.4962],
#         [ 6.8829, -0.3666]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5617, -0.2967],
#         [-0.1199,  7.7465],
#         [-1.6806,  1.4966],
#         [ 6.8840, -0.3667]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5628, -0.2969],
#         [-0.1200,  7.7477],
#         [-1.6809,  1.4969],
#         [ 6.8849, -0.3665]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5639, -0.2971],
#         [-0.1199,  7.7487],
#         [-1.6813,  1.4973],
#         [ 6.8860, -0.3664]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5651, -0.2974],
#         [-0.1199,  7.7497],
#         [-1.6816,  1.4976],
#         [ 6.8871, -0.3664]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5662, -0.2975],
#         [-0.1197,  7.7507],
#         [-1.6820,  1.4980],
#         [ 6.8882, -0.3664]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5673, -0.2976],
#         [-0.1196,  7.7516],
#         [-1.6823,  1.4983],
#         [ 6.8893, -0.3664]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5685, -0.2979],
#         [-0.1193,  7.7523],
#         [-1.6827,  1.4987],
#         [ 6.8906, -0.3666]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5697, -0.2982],
#         [-0.1190,  7.7530],
#         [-1.6830,  1.4990],
#         [ 6.8918, -0.3668]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5709, -0.2985],
#         [-0.1188,  7.7537],
#         [-1.6834,  1.4993],
#         [ 6.8931, -0.3671]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5720, -0.2988],
#         [-0.1187,  7.7543],
#         [-1.6837,  1.4997],
#         [ 6.8943, -0.3674]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5732, -0.2990],
#         [-0.1185,  7.7548],
#         [-1.6840,  1.5000],
#         [ 6.8957, -0.3678]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5743, -0.2992],
#         [-0.1182,  7.7553],
#         [-1.6844,  1.5004],
#         [ 6.8971, -0.3683]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5755, -0.2995],
#         [-0.1181,  7.7559],
#         [-1.6847,  1.5007],
#         [ 6.8985, -0.3686]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5767, -0.2997],
#         [-0.1180,  7.7565],
#         [-1.6851,  1.5011],
#         [ 6.8998, -0.3690]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5779, -0.2999],
#         [-0.1179,  7.7572],
#         [-1.6854,  1.5014],
#         [ 6.9011, -0.3693]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5790, -0.3002],
#         [-0.1179,  7.7579],
#         [-1.6858,  1.5018],
#         [ 6.9024, -0.3697]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5802, -0.3004],
#         [-0.1177,  7.7584],
#         [-1.6861,  1.5021],
#         [ 6.9038, -0.3701]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5814, -0.3007],
#         [-0.1174,  7.7589],
#         [-1.6865,  1.5025],
#         [ 6.9054, -0.3706]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5826, -0.3009],
#         [-0.1172,  7.7594],
#         [-1.6868,  1.5028],
#         [ 6.9068, -0.3710]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5839, -0.3011],
#         [-0.1169,  7.7600],
#         [-1.6871,  1.5031],
#         [ 6.9082, -0.3714]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5851, -0.3014],
#         [-0.1168,  7.7606],
#         [-1.6875,  1.5035],
#         [ 6.9096, -0.3718]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5863, -0.3016],
#         [-0.1167,  7.7612],
#         [-1.6878,  1.5038],
#         [ 6.9111, -0.3723]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5875, -0.3019],
#         [-0.1165,  7.7617],
#         [-1.6882,  1.5042],
#         [ 6.9125, -0.3727]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5887, -0.3021],
#         [-0.1162,  7.7623],
#         [-1.6885,  1.5045],
#         [ 6.9139, -0.3731]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5900, -0.3024],
#         [-0.1160,  7.7628],
#         [-1.6889,  1.5049],
#         [ 6.9153, -0.3734]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5912, -0.3026],
#         [-0.1159,  7.7635],
#         [-1.6892,  1.5052],
#         [ 6.9167, -0.3737]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5925, -0.3029],
#         [-0.1158,  7.7643],
#         [-1.6896,  1.5056],
#         [ 6.9181, -0.3740]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5938, -0.3031],
#         [-0.1157,  7.7651],
#         [-1.6897,  1.5058],
#         [ 6.9196, -0.3742]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5927, -0.3029],
#         [-0.1169,  7.7657],
#         [-1.6902,  1.5062],
#         [ 6.9177, -0.3739]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5919, -0.3027],
#         [-0.1180,  7.7665],
#         [-1.6906,  1.5066],
#         [ 6.9161, -0.3735]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5913, -0.3025],
#         [-0.1190,  7.7673],
#         [-1.6909,  1.5069],
#         [ 6.9149, -0.3732]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5909, -0.3024],
#         [-0.1199,  7.7681],
#         [-1.6913,  1.5073],
#         [ 6.9140, -0.3730]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5907, -0.3024],
#         [-0.1207,  7.7691],
#         [-1.6916,  1.5076],
#         [ 6.9134, -0.3729]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5906, -0.3023],
#         [-0.1214,  7.7700],
#         [-1.6920,  1.5080],
#         [ 6.9130, -0.3728]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5908, -0.3023],
#         [-0.1219,  7.7710],
#         [-1.6923,  1.5083],
#         [ 6.9129, -0.3727]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5910, -0.3023],
#         [-0.1224,  7.7720],
#         [-1.6927,  1.5087],
#         [ 6.9130, -0.3728]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5913, -0.3024],
#         [-0.1228,  7.7731],
#         [-1.6930,  1.5090],
#         [ 6.9132, -0.3728]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5917, -0.3025],
#         [-0.1232,  7.7741],
#         [-1.6933,  1.5093],
#         [ 6.9136, -0.3729]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5923, -0.3026],
#         [-0.1236,  7.7753],
#         [-1.6937,  1.5097],
#         [ 6.9142, -0.3730]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5929, -0.3027],
#         [-0.1239,  7.7765],
#         [-1.6940,  1.5100],
#         [ 6.9148, -0.3731]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5936, -0.3028],
#         [-0.1242,  7.7777],
#         [-1.6944,  1.5104],
#         [ 6.9155, -0.3733]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5944, -0.3030],
#         [-0.1244,  7.7789],
#         [-1.6947,  1.5107],
#         [ 6.9165, -0.3734]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5952, -0.3031],
#         [-0.1245,  7.7800],
#         [-1.6951,  1.5111],
#         [ 6.9175, -0.3737]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5961, -0.3033],
#         [-0.1246,  7.7812],
#         [-1.6954,  1.5114],
#         [ 6.9186, -0.3739]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5971, -0.3035],
#         [-0.1248,  7.7825],
#         [-1.6957,  1.5117],
#         [ 6.9196, -0.3738]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5980, -0.3037],
#         [-0.1248,  7.7836],
#         [-1.6961,  1.5121],
#         [ 6.9206, -0.3736]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.5991, -0.3039],
#         [-0.1248,  7.7847],
#         [-1.6964,  1.5124],
#         [ 6.9216, -0.3735]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6001, -0.3041],
#         [-0.1248,  7.7857],
#         [-1.6968,  1.5128],
#         [ 6.9227, -0.3734]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6012, -0.3043],
#         [-0.1248,  7.7868],
#         [-1.6971,  1.5131],
#         [ 6.9238, -0.3734]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6023, -0.3045],
#         [-0.1248,  7.7878],
#         [-1.6975,  1.5135],
#         [ 6.9249, -0.3733]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6033, -0.3047],
#         [-0.1247,  7.7886],
#         [-1.6978,  1.5138],
#         [ 6.9261, -0.3734]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6045, -0.3049],
#         [-0.1245,  7.7894],
#         [-1.6981,  1.5141],
#         [ 6.9274, -0.3736]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6056, -0.3051],
#         [-0.1243,  7.7901],
#         [-1.6985,  1.5145],
#         [ 6.9286, -0.3738]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6068, -0.3054],
#         [-0.1242,  7.7908],
#         [-1.6988,  1.5148],
#         [ 6.9299, -0.3740]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6079, -0.3057],
#         [-0.1241,  7.7915],
#         [-1.6992,  1.5152],
#         [ 6.9311, -0.3743]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6091, -0.3059],
#         [-0.1239,  7.7920],
#         [-1.6995,  1.5155],
#         [ 6.9325, -0.3747]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6102, -0.3061],
#         [-0.1236,  7.7926],
#         [-1.6999,  1.5159],
#         [ 6.9339, -0.3751]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6114, -0.3064],
#         [-0.1234,  7.7931],
#         [-1.7002,  1.5162],
#         [ 6.9352, -0.3755]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6126, -0.3066],
#         [-0.1233,  7.7938],
#         [-1.7005,  1.5165],
#         [ 6.9366, -0.3758]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6137, -0.3069],
#         [-0.1232,  7.7944],
#         [-1.7009,  1.5169],
#         [ 6.9379, -0.3762]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6149, -0.3071],
#         [-0.1229,  7.7950],
#         [-1.7012,  1.5172],
#         [ 6.9393, -0.3766]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6161, -0.3074],
#         [-0.1226,  7.7955],
#         [-1.7016,  1.5176],
#         [ 6.9407, -0.3770]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6174, -0.3076],
#         [-0.1224,  7.7961],
#         [-1.7019,  1.5179],
#         [ 6.9421, -0.3774]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6186, -0.3078],
#         [-0.1223,  7.7966],
#         [-1.7023,  1.5182],
#         [ 6.9435, -0.3778]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6198, -0.3081],
#         [-0.1221,  7.7972],
#         [-1.7020,  1.5185],
#         [ 6.9449, -0.3782]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6186, -0.3078],
#         [-0.1233,  7.7977],
#         [-1.7029,  1.5189],
#         [ 6.9434, -0.3788]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6176, -0.3076],
#         [-0.1245,  7.7982],
#         [-1.7033,  1.5193],
#         [ 6.9418, -0.3788]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6169, -0.3074],
#         [-0.1255,  7.7988],
#         [-1.7036,  1.5196],
#         [ 6.9404, -0.3784]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6163, -0.3072],
#         [-0.1264,  7.7995],
#         [-1.7040,  1.5200],
#         [ 6.9393, -0.3782]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6160, -0.3071],
#         [-0.1271,  7.8002],
#         [-1.7043,  1.5203],
#         [ 6.9385, -0.3780]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6158, -0.3071],
#         [-0.1278,  7.8010],
#         [-1.7046,  1.5206],
#         [ 6.9380, -0.3779]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6158, -0.3071],
#         [-0.1284,  7.8018],
#         [-1.7050,  1.5210],
#         [ 6.9378, -0.3778]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6159, -0.3071],
#         [-0.1288,  7.8026],
#         [-1.7053,  1.5213],
#         [ 6.9378, -0.3778]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6162, -0.3071],
#         [-0.1292,  7.8035],
#         [-1.7057,  1.5217],
#         [ 6.9380, -0.3778]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6165, -0.3072],
#         [-0.1294,  7.8044],
#         [-1.7060,  1.5220],
#         [ 6.9384, -0.3779]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6170, -0.3073],
#         [-0.1296,  7.8054],
#         [-1.7064,  1.5223],
#         [ 6.9389, -0.3780]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6176, -0.3074],
#         [-0.1299,  7.8065],
#         [-1.7067,  1.5227],
#         [ 6.9394, -0.3781]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6182, -0.3075],
#         [-0.1302,  7.8076],
#         [-1.7070,  1.5230],
#         [ 6.9401, -0.3783]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6189, -0.3076],
#         [-0.1303,  7.8088],
#         [-1.7074,  1.5234],
#         [ 6.9410, -0.3784]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6197, -0.3078],
#         [-0.1304,  7.8098],
#         [-1.7077,  1.5237],
#         [ 6.9420, -0.3787]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6206, -0.3079],
#         [-0.1304,  7.8109],
#         [-1.7081,  1.5241],
#         [ 6.9431, -0.3789]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6215, -0.3081],
#         [-0.1304,  7.8121],
#         [-1.7084,  1.5244],
#         [ 6.9442, -0.3791]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6224, -0.3083],
#         [-0.1305,  7.8133],
#         [-1.7087,  1.5247],
#         [ 6.9454, -0.3794]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6234, -0.3085],
#         [-0.1306,  7.8145],
#         [-1.7091,  1.5251],
#         [ 6.9466, -0.3796]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6244, -0.3087],
#         [-0.1306,  7.8156],
#         [-1.7094,  1.5254],
#         [ 6.9478, -0.3794]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6254, -0.3089],
#         [-0.1305,  7.8166],
#         [-1.7098,  1.5258],
#         [ 6.9489, -0.3793]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6265, -0.3091],
#         [-0.1306,  7.8177],
#         [-1.7101,  1.5261],
#         [ 6.9500, -0.3792]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6276, -0.3094],
#         [-0.1306,  7.8186],
#         [-1.7104,  1.5264],
#         [ 6.9512, -0.3792]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6287, -0.3096],
#         [-0.1304,  7.8195],
#         [-1.7108,  1.5268],
#         [ 6.9524, -0.3793]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6298, -0.3098],
#         [-0.1304,  7.8204],
#         [-1.7111,  1.5271],
#         [ 6.9536, -0.3793]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6309, -0.3100],
#         [-0.1303,  7.8213],
#         [-1.7115,  1.5275],
#         [ 6.9549, -0.3794]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6320, -0.3103],
#         [-0.1303,  7.8222],
#         [-1.7118,  1.5278],
#         [ 6.9561, -0.3795]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6332, -0.3105],
#         [-0.1302,  7.8230],
#         [-1.7121,  1.5281],
#         [ 6.9574, -0.3797]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6345, -0.3108],
#         [-0.1300,  7.8237],
#         [-1.7125,  1.5285],
#         [ 6.9587, -0.3799]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6357, -0.3110],
#         [-0.1297,  7.8244],
#         [-1.7128,  1.5288],
#         [ 6.9601, -0.3801]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6369, -0.3113],
#         [-0.1295,  7.8250],
#         [-1.7132,  1.5292],
#         [ 6.9615, -0.3804]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6381, -0.3115],
#         [-0.1292,  7.8257],
#         [-1.7135,  1.5295],
#         [ 6.9628, -0.3806]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6394, -0.3118],
#         [-0.1290,  7.8263],
#         [-1.7138,  1.5298],
#         [ 6.9642, -0.3809]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6406, -0.3120],
#         [-0.1288,  7.8270],
#         [-1.7142,  1.5302],
#         [ 6.9655, -0.3812]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6418, -0.3123],
#         [-0.1287,  7.8277],
#         [-1.7145,  1.5305],
#         [ 6.9669, -0.3815]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6430, -0.3125],
#         [-0.1285,  7.8284],
#         [-1.7149,  1.5309],
#         [ 6.9683, -0.3819]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6442, -0.3128],
#         [-0.1284,  7.8291],
#         [-1.7152,  1.5312],
#         [ 6.9696, -0.3821]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6455, -0.3130],
#         [-0.1282,  7.8297],
#         [-1.7155,  1.5315],
#         [ 6.9710, -0.3825]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6468, -0.3133],
#         [-0.1280,  7.8303],
#         [-1.7159,  1.5319],
#         [ 6.9725, -0.3829]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6481, -0.3136],
#         [-0.1276,  7.8308],
#         [-1.7162,  1.5322],
#         [ 6.9739, -0.3832]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6493, -0.3138],
#         [-0.1273,  7.8313],
#         [-1.7166,  1.5325],
#         [ 6.9753, -0.3836]], grad_fn=<AddmmBackward0>)
# tensor([[ 6.6506, -0.3141],
#         [-0.1270,  7.8318],
#         [-1.7169,  1.5329],
#         [ 6.9767, -0.3840]], grad_fn=<AddmmBackward0>)

# %%
model(x[20:21])
# Out:
# tensor([39.5272], grad_fn=<AddBackward0>)
